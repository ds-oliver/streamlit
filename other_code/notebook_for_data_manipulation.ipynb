# %%
! pip install -r /Users/hogan/Library/CloudStorage/Dropbox/Mac/Documents/GitHub/streamlit/requirements.txt
# Out:
# ...
#   Using cached annotated_types-0.5.0-py3-none-any.whl (11 kB)
# ...
#   Using cached anyio-3.7.0-py3-none-any.whl (80 kB)
# ...
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# ...
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# ...
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# ...
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# ...
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 1.5 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached cffi-1.15.1-cp311-cp311-macosx_10_9_x86_64.whl (179 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 1.4 MB/s eta 0:00:0000:01
# ...
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# ...
#   Using cached contourpy-1.1.0-cp311-cp311-macosx_10_9_x86_64.whl (243 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
from requests.exceptions import RequestException, Timeout
import numpy as np
import uuid
from datetime import datetime
import pickle
import unidecode
import re
import os
import glob

# %%
output_path = '/Users/hogan/Library/CloudStorage/Dropbox/Mac/Documents/GitHub/streamlit/data'

data_to_load_path = output_path

# load the dataframes naming the df by the csv file name
def load_data():
    list_of_files = glob.glob(data_to_load_path + '/*.csv')
    list_of_files.sort()

    # create a list of the csv filenames so we can use them as df names
    list_of_df_names = []
    for file in list_of_files:
        list_of_df_names.append(file.split('/')[-1].split('.')[0])
        # if first file rename
        if file == list_of_files[0]:
            list_of_df_names[0] = 'all_seasons_combined_df'
        # if second file rename
        if file == list_of_files[1]:
            list_of_df_names[1] = 'all_shots_all_df_combined'
        # if third file rename
        if file == list_of_files[2]:
            list_of_df_names[2] = 'df_2017_2018'
        # if fourth file rename
        if file == list_of_files[3]:
            list_of_df_names[3] = 'df_2018_2019'
        # if fifth file rename
        if file == list_of_files[4]:
            list_of_df_names[4] = 'df_2019_2020'
        # if sixth file rename
        if file == list_of_files[5]:
            list_of_df_names[5] = 'df_2020_2021'
        # if seventh file rename
        if file == list_of_files[6]:
            list_of_df_names[6] = 'df_2021_2022'
        # if eighth file rename
        if file == list_of_files[7]:
            list_of_df_names[7] = 'df_2022_2023'
        # if ninth file rename
        if file == list_of_files[8]:
            list_of_df_names[8] = 'df_1992_2016'
        
    # create a dictionary of the dataframes
    dict_of_results_dfs = {}
    dict_of_players_dfs = {}
    for i in enumerate(list_of_files):
        # first two files are results
        if i[0] < 2:
            dict_of_results_dfs[list_of_df_names[i[0]]] = pd.read_csv(i[1])
        # last 7 files are players
        else:
            dict_of_players_dfs[list_of_df_names[i[0]]] = pd.read_csv(i[1])

    list_of_results_df_names = []
    # create list of df names to use in the app
    for key in dict_of_results_dfs.keys():
        list_of_results_df_names.append(key)

    list_of_players_df_names = []
    # create list of df names to use in the app
    for key in dict_of_players_dfs.keys():
        list_of_players_df_names.append(key)

    return dict_of_results_dfs, dict_of_players_dfs, list_of_results_df_names, list_of_players_df_names

# %%
def main():
    dict_of_results_dfs, dict_of_players_dfs, list_of_results_df_names, list_of_players_df_names = load_data()

    # concat the dataframes in each dictionary
    results_df = pd.concat(dict_of_results_dfs, axis=1)
    players_df = pd.concat(dict_of_players_dfs, axis=1)

# %%
if __name__ == "__main__":
    main()
# Out:
# /var/folders/ks/15n3rzvs5tv_cwvpr7k4mkth0000gn/T/ipykernel_84906/1101146661.py:45: DtypeWarning: Columns (109) have mixed types. Specify dtype option on import or set low_memory=False.
#   dict_of_dfs[list_of_df_names[i]] = pd.read_csv(list_of_files[i])
# all_seasons_combined_df
#    Unnamed: 0               player  shirtnumber nationality  age  minutes  \
# 0           0  Alexandre Lacazette            9         FRA   26     90.0
# 1           1        Danny Welbeck           23         ENG   26     74.0
# 2           2         Theo Walcott           14         ENG   28     16.0
# 3           3           Mesut Ozil           11         GER   28     90.0
# 4           4         Granit Xhaka           29         SUI   24     90.0
#
#    goals  assists  pens_made  pens_att  ...  aerials_won_pct  home     team  \
# 0      1        0          0         0  ...             33.3  True  Arsenal
# 1      1        0          0         0  ...             50.0  True  Arsenal
# ...

# %%
# create new list of df names to use in the app
list_of_df_names = ['all_seasons_combined_df', 'all_shots_all_df_combined', 'df_2017_2018', 'df_2018_2019', 'df_2019_2020', 'df_2020_2021', 'df_2021_2022', 'df_2022_2023', 'df_1992_2016']

# concatenate the dataframes with this name df_2017_2018 structure
